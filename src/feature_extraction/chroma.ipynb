# %%
import numpy as np

def chroma_from_stft(stft_matrix, sr, n_fft):
    """
    stft_matrix: shape (freq_bins, time_frames)
    sr          : sample rate
    n_fft       : FFT size
    """
    num_bins, num_frames = stft_matrix.shape
    chroma = np.zeros((12, num_frames))

    for t in range(num_frames):
        for k in range(1, num_bins):
            magnitude = stft_matrix[k, t]
            f_k = k * sr / n_fft

            if f_k < 20:
                continue

            p = 12 * np.log2(f_k / 440.0)
            chroma_idx = int(np.round(p)) % 12
            chroma[chroma_idx, t] += magnitude

    return chroma

# %%
import os
import numpy as np

stft_dir   = r"D:\FPT_prj\preprocess_data\speech\stft"
chroma_dir = r"D:\FPT_prj\preprocess_data\speech\chroma"
os.makedirs(chroma_dir, exist_ok=True)

sr = 16000
n_fft = 512

for i in range(30, 101):
    stft_path = os.path.join(stft_dir, f"{i}_stft.npy")

    if not os.path.exists(stft_path):
        print(f"Missing STFT: {i}_stft.npy")
        continue

    # load STFT magnitude
    stft = np.load(stft_path)

    # EXPECT (time, freq) → transpose
    if stft.shape[0] < stft.shape[1]:
        stft = stft.T   # (freq, time)

    # Ensure non-negative
    stft = np.abs(stft)

    chroma = chroma_from_stft(stft, sr, n_fft)

    save_path = os.path.join(chroma_dir, f"{i}_chroma.npy")
    np.save(save_path, chroma)

    print(f"{i}_stft.npy → chroma shape: {chroma.shape}, sum={chroma.sum():.4f}")
# Out:
# 30_stft.npy → chroma shape: (12, 257), sum=3974129.8255
# 31_stft.npy → chroma shape: (12, 257), sum=3309593.9338
# 32_stft.npy → chroma shape: (12, 257), sum=915469.2102
# 33_stft.npy → chroma shape: (12, 257), sum=2655984.2206
# 34_stft.npy → chroma shape: (12, 257), sum=2890326.7143
# 35_stft.npy → chroma shape: (12, 257), sum=5494148.9223
# 36_stft.npy → chroma shape: (12, 257), sum=3890761.4398
# 37_stft.npy → chroma shape: (12, 257), sum=4809833.9695
# 38_stft.npy → chroma shape: (12, 257), sum=5790432.8697
# 39_stft.npy → chroma shape: (12, 257), sum=5552805.4939
# 40_stft.npy → chroma shape: (12, 257), sum=1766744.5181
# 41_stft.npy → chroma shape: (12, 257), sum=1951076.8584
# 42_stft.npy → chroma shape: (12, 257), sum=3286866.1731
# 43_stft.npy → chroma shape: (12, 257), sum=3263194.6863
# 44_stft.npy → chroma shape: (12, 257), sum=3612945.6760
# 45_stft.npy → chroma shape: (12, 257), sum=4545662.9637
# 46_stft.npy → chroma shape: (12, 257), sum=3751130.9260
# 47_stft.npy → chroma shape: (12, 257), sum=3857743.0556
# 48_stft.npy → chroma shape: (12, 257), sum=2982568.1287
# 49_stft.npy → chroma shape: (12, 257), sum=2628844.4398
# 50_stft.npy → chroma shape: (12, 257), sum=4512410.4376
# 51_stft.npy → chroma shape: (12, 257), sum=3259082.6147
# 52_stft.npy → chroma shape: (12, 257), sum=4060851.0955
# 53_stft.npy → chroma shape: (12, 257), sum=1996151.3660
# 54_stft.npy → chroma shape: (12, 257), sum=2597632.6062
# 55_stft.npy → chroma shape: (12, 257), sum=2742003.6250
# 56_stft.npy → chroma shape: (12, 257), sum=4033457.6968
# 57_stft.npy → chroma shape: (12, 257), sum=2099127.4504
# 58_stft.npy → chroma shape: (12, 257), sum=3544201.0170
# 59_stft.npy → chroma shape: (12, 257), sum=2949516.7275
# 60_stft.npy → chroma shape: (12, 257), sum=2976568.1854
# 61_stft.npy → chroma shape: (12, 257), sum=2633104.9459
# 62_stft.npy → chroma shape: (12, 257), sum=2629755.1321
# 63_stft.npy → chroma shape: (12, 257), sum=2866286.4350
# 64_stft.npy → chroma shape: (12, 257), sum=4264085.2734
# 65_stft.npy → chroma shape: (12, 257), sum=3457926.2019
# 66_stft.npy → chroma shape: (12, 257), sum=1525364.1418
# 67_stft.npy → chroma shape: (12, 257), sum=2277066.4528
# 68_stft.npy → chroma shape: (12, 257), sum=2425864.0636
# 69_stft.npy → chroma shape: (12, 257), sum=3151423.2952
# 70_stft.npy → chroma shape: (12, 257), sum=4346054.5932
# 71_stft.npy → chroma shape: (12, 257), sum=4374271.6950
# 72_stft.npy → chroma shape: (12, 257), sum=3875598.8219
# 73_stft.npy → chroma shape: (12, 257), sum=2406418.4018
# 74_stft.npy → chroma shape: (12, 257), sum=3997728.2687
# 75_stft.npy → chroma shape: (12, 257), sum=2919354.6537
# 76_stft.npy → chroma shape: (12, 257), sum=3289644.9169
# 77_stft.npy → chroma shape: (12, 257), sum=2463418.2067
# 78_stft.npy → chroma shape: (12, 257), sum=2112217.0269
# 79_stft.npy → chroma shape: (12, 257), sum=5430790.5539
# 80_stft.npy → chroma shape: (12, 257), sum=2815879.9616
# 81_stft.npy → chroma shape: (12, 257), sum=3823840.0574
# 82_stft.npy → chroma shape: (12, 257), sum=2128522.0073
# 83_stft.npy → chroma shape: (12, 257), sum=1323202.7814
# 84_stft.npy → chroma shape: (12, 257), sum=4506318.4973
# 85_stft.npy → chroma shape: (12, 257), sum=4098004.3492
# 86_stft.npy → chroma shape: (12, 257), sum=1302475.4730
# 87_stft.npy → chroma shape: (12, 257), sum=4042359.7302
# 88_stft.npy → chroma shape: (12, 257), sum=2645763.2305
# 89_stft.npy → chroma shape: (12, 257), sum=3300254.4764
# 90_stft.npy → chroma shape: (12, 257), sum=1954600.9460
# 91_stft.npy → chroma shape: (12, 257), sum=4007173.0859
# 92_stft.npy → chroma shape: (12, 257), sum=1017699.8762
# 93_stft.npy → chroma shape: (12, 257), sum=2759436.0977
# 94_stft.npy → chroma shape: (12, 257), sum=3765923.8501
# 95_stft.npy → chroma shape: (12, 257), sum=2247950.1988
# 96_stft.npy → chroma shape: (12, 257), sum=3754144.2523
# 97_stft.npy → chroma shape: (12, 257), sum=3888683.9441
# 98_stft.npy → chroma shape: (12, 257), sum=3931072.2456
# 99_stft.npy → chroma shape: (12, 257), sum=3668250.9992
# 100_stft.npy → chroma shape: (12, 257), sum=2254739.0610
