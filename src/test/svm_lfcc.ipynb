# %%
import numpy as np

from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold, cross_validate

# %%
X_1 = np.load("C:/Users/Vinh/Documents/Pythonfile/Voice-Activity-Detect/data/feature/test/speech/lfcc_speech.npy")  # label = 1
X_0 = np.load("C:/Users/Vinh/Documents/Pythonfile/Voice-Activity-Detect/data/feature/test/non-speech/lfcc_non-speech.npy")  # label = 0

print("X_1:", X_1.shape)
print("X_0:", X_0.shape)
y_1 = np.ones(X_1.shape[0], dtype=int)   # toàn 1
y_0 = np.zeros(X_0.shape[0], dtype=int)  # toàn 0
X = np.vstack([X_1, X_0])
y = np.hstack([y_1, y_0])

print("X:", X.shape)
print("y:", y.shape)
idx = np.random.permutation(len(y))
X = X[idx]
y = y[idx]
# Out:
# X_1: (66211, 257)
# X_0: (137769, 257)
# X: (203980, 257)
# y: (203980,)

# %%
svm_model = Pipeline([
    ("scaler", StandardScaler()),
    ("svm", LinearSVC(
        C=1.0,          # soft-margin
        loss="hinge",
        max_iter=10000
    ))
])

# %%
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

# %%
scoring = {
    "acc": "accuracy",
    "precision": "precision",
    "recall": "recall",
    "f1": "f1"
}

cv_results = cross_validate(
    svm_model,
    X,
    y,
    cv=cv,
    scoring=scoring,
    n_jobs=-1
)

# %%
for metric in scoring.keys():
    scores = cv_results[f"test_{metric}"]
    print(f"{metric.upper():9s} | "
          f"Mean = {scores.mean():.4f} | "
          f"Std = {scores.std():.4f}")
# Out:
# ACC       | Mean = 0.9639 | Std = 0.0011
# PRECISION | Mean = 0.9339 | Std = 0.0022
# RECALL    | Mean = 0.9564 | Std = 0.0022
# F1        | Mean = 0.9450 | Std = 0.0017
