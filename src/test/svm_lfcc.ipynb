# %%
import numpy as np

from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold, cross_validate

# %%
X_1 = np.load("C:/Users/Vinh/Documents/Pythonfile/Voice-Activity-Detect/data/feature/test/speech/lfcc_speech.npy")  # label = 1
X_0 = np.load("C:/Users/Vinh/Documents/Pythonfile/Voice-Activity-Detect/data/feature/test/non-speech/lfcc_non-speech.npy")  # label = 0

print("X_1:", X_1.shape)
print("X_0:", X_0.shape)
y_1 = np.ones(X_1.shape[0], dtype=int)   # toàn 1
y_0 = np.zeros(X_0.shape[0], dtype=int)  # toàn 0
X = np.vstack([X_1, X_0])
y = np.hstack([y_1, y_0])

print("X:", X.shape)
print("y:", y.shape)
idx = np.random.permutation(len(y))
X = X[idx]
y = y[idx]
# Out:
# X_1: (678247, 13)
# X_0: (277674, 13)
# X: (955921, 13)
# y: (955921,)

# %%
svm_model = Pipeline([
    ("scaler", StandardScaler()),
    ("svm", LinearSVC(
        C=1.0,          # soft-margin
        loss="hinge",
        max_iter=10000
    ))
])

# %%
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

# %%
scoring = {
    "acc": "accuracy",
    "precision": "precision",
    "recall": "recall",
    "f1": "f1"
}

cv_results = cross_validate(
    svm_model,
    X,
    y,
    cv=cv,
    scoring=scoring,
    n_jobs=-1
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 8
#       1 scoring = {
#       2     "acc": "accuracy",
#       3     "precision": "precision",
#       4     "recall": "recall",
#       5     "f1": "f1"
#       6 }
# ----> 8 cv_results = cross_validate(
#       9     svm_model,
#      10     X,
#      11     y,
#      12     cv=cv,
#      13     scoring=scoring,
#      14     n_jobs=-1
#      15 )
#
# File c:\Users\Vinh\Documents\Pythonfile\Voice-Activity-Detect\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
# ...

# %%
for metric in scoring.keys():
    scores = cv_results[f"test_{metric}"]
    print(f"{metric.upper():9s} | "
          f"Mean = {scores.mean():.4f} | "
          f"Std = {scores.std():.4f}")
