# %%
import numpy as np
import os



DIR = "D:/Pythonfile/Voice-Activity-Detect/data/feature/train"


npy_files = sorted([
        os.path.join(DIR, f)
        for f in os.listdir(DIR)
        if f.lower().endswith(".npy")
    ])

for path in npy_files:
    print(path)
    item = path.split('\\')
    X = np.load(path)
    print(item[1], X.shape)
# Out:
# D:/Pythonfile/Voice-Activity-Detect/data/feature/train\lfcc_non-speech_1.npy
# lfcc_non-speech_1.npy (10944158, 60)
# D:/Pythonfile/Voice-Activity-Detect/data/feature/train\lfcc_non-speech_2.npy
# lfcc_non-speech_2.npy (1688068, 60)
# D:/Pythonfile/Voice-Activity-Detect/data/feature/train\mfcc_non-speech_1.npy
# mfcc_non-speech_1.npy (10945435, 39)
# D:/Pythonfile/Voice-Activity-Detect/data/feature/train\mfcc_non-speech_2.npy
# mfcc_non-speech_2.npy (1690400, 39)
# D:/Pythonfile/Voice-Activity-Detect/data/feature/train\mfcc_speech.npy
# mfcc_speech.npy (12846082, 39)
# D:/Pythonfile/Voice-Activity-Detect/data/feature/train\mini_lfcc_non-speech_1.npy
# mini_lfcc_non-speech_1.npy (1094415, 60)
# D:/Pythonfile/Voice-Activity-Detect/data/feature/train\mini_lfcc_non-speech_2.npy
# mini_lfcc_non-speech_2.npy (168465, 60)
# D:/Pythonfile/Voice-Activity-Detect/data/feature/train\mini_lfcc_speech.npy
# mini_lfcc_speech.npy (1253962, 60)
# ...
